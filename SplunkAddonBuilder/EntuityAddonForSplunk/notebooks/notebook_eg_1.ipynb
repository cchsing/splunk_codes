# %%
import pandas as pd
import numpy as np
import json

# %%
data_file = "../data/test_data_liveMeasure"
data = []
with open(data_file, 'r') as f:
    data = json.load(f)

# %%
keys_0 = list(data[0].keys())
for key in keys_0:
    print(key)
# Out:
# Measure Details for MYWCBP1PLADBS01:50000:Microsoft SQL

# %%
data[0][keys_0[0]]
# Out:
# [{'Disk Activity': {'State': 'GOOD',
#    'Last Measurement Time': 'Feb 28, 2023 16:17:23',
#    'Disk0 C:': [{'State': 'GOOD',
#      'Disk busy  ': [{'State': 'GOOD', 'Value': '0.5091', 'Unit': '%'}],
#      'Disk busy due to reads  ': [{'State': 'GOOD',
#        'Value': '0.1531',
#        'Unit': '%'}],
#      'Disk busy due to writes  ': [{'State': 'GOOD',
#        'Value': '0.356',
#        'Unit': '%'}],
#      'Disk read time  ': [{'State': 'GOOD',
#        'Value': '0.0008',
#        'Unit': 'Seconds'}],
#      'Disk write time  ': [{'State': 'GOOD',
#        'Value': '0.0003',
#        'Unit': 'Seconds'}],
#      'Avg queue length  ': [{'State': 'GOOD',
#        'Value': '0.0051',
#        'Unit': 'Number'}],
#      'Current disk queue length  ': [{'State': 'GOOD',
#        'Value': '0',
#        'Unit': 'Number'}],
#      'Disk read rate  ': [{'State': 'GOOD',
#        'Value': '1.9989',
#        'Unit': 'Reads/sec'}],
# ...

# %%
type(data[0][keys_0[0]])
# Out:
# list

# %%
for i in data[0][keys_0[0]]:
    print("---------------------------------------------------------------")
    print(type(i))
    print(json.dumps(i,indent=4))
    print("***************************************************************")
# Out:
# ---------------------------------------------------------------
# <class 'dict'>
# {
#     "Disk Activity": {
#         "State": "GOOD",
#         "Last Measurement Time": "Feb 28, 2023 16:17:23",
#         "Disk0 C:": [
#             {
#                 "State": "GOOD",
#                 "Disk busy  ": [
#                     {
#                         "State": "GOOD",
#                         "Value": "0.5091",
#                         "Unit": "%"
#                     }
#                 ],
#                 "Disk busy due to reads  ": [
#                     {
#                         "State": "GOOD",
#                         "Value": "0.1531",
#                         "Unit": "%"
#                     }
#                 ],
#                 "Disk busy due to writes  ": [
#                     {
#                         "State": "GOOD",
#                         "Value": "0.356",
#                         "Unit": "%"
#                     }
#                 ],
# ...
